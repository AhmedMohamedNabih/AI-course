# %% [markdown]
# **video games sales database**
# the dataset was generated by scraping data from (vgchartz.com)
# VGChartz sits at the center of the network and is a video game sales tracking website, providing weekly sales figures of console software and hardware by region.
# in this dataset we use(pandas,numpay,seaborn,matplotlib)
# dataset consists of(Rank,name,platform,year,genre,publisher,NA_Sales,EU_sales,Other_Sales,Global_Sales).
# df = pd.read_csv('vgsales.csv')-> to import data
# df.info()->to know the number of row and columns and know datatype and non null values.
# we have a missing data in this dataset(271 in year_col and 58 in publisher col )
# df.describe()->have all numeric data(main-count-min-standard deviation).
#
# --------------------------------------------------------------------------
# top 10 selling games in gloabal sales=(wii sports-super mario bros-wii sports resort- pokemon-red- tetris- new super mario bros- wii play- new super mario bros.wii- duch hunt  )
#
# The chart shows the sales data in millions for the following games (from highest to lowest sales):
#
# Wii Sports (highest sales, approximately 80 million)
# Super Mario Bros.
# Mario Kart Wii
# Wii Sports Resort
# Pokemon Red/Pokemon Blue
# Tetris
# New Super Mario Bros.
# Wii Play
# New Super Mario Bros. Wii
# Duck Hunt (approximately 30 million sales)
# Each bar corresponds to the global sales figures of the respective game, and the chart highlights how Wii Sports significantly outperforms the others in terms of sales.
#
#
#
#
#
#
#
# ![WhatsApp Image 2024-09-22 at 21.08.09_9f227bae.jpg](data:image/jpeg;base64,...)
#
# --------------------------------------------------------------------------
#  ps2 has the highst total sales
#
#  all companies cares of ps2 and make new games for ps2
#
#  PS2 leads by a substantial margin.
# Platforms such as Xbox 360, PS3, and Wii also have significant total sales.
# There is a steep decline in total sales for platforms after the top 6.
# PC, PS4, and GB have similar sales figures but lower compared to the leading platforms.
#
#  ![WhatsApp Image 2024-09-22 at 21.38.56_6fe2cad4.jpg](data:image/jpeg;base64,...)
#  -------------------------------------------------------------------------
#
#  the most popular genres in video games using pie chart
#  (action-sports-shooter-Role_playing-plat_form-misc-Racing-fighting)
#
#  Action games lead the market by a large margin, accounting for almost one-fifth of global sales.
# Sports and Shooter games also have a significant impact, making up over a quarter of total sales combined.
# Genres like Simulation, Adventure, and Strategy occupy much smaller portions of the sales market, each with less than 3%.
# This chart provides a clear visual representation of how different game genres contribute to global sales, with action games being the most dominant genre.
#
# ![WhatsApp Image 2024-09-22 at 21.46.29_ca9eb9c8.jpg](data:image/jpeg;base64,...)
# --------------------------------------------------------------------------
# the most total seles by region
#
# North America (NA) has the highest total sales, exceeding 4000 million.
# Europe (EU) follows with total sales exceeding 2000 million but significantly lower than North America.
# Japan (JP) shows sales around 1200 million, less than half of Europe's sales.
# Other regions combined have the lowest sales, just under 800 million.
# Overall, the chart suggests that North America is the most significant market for the product/service, followed by Europe and then Japan. The "Other regions" category is notably smaller than the top three.
#
#
# ![WhatsApp Image 2024-09-22 at 21.55.46_d0c1ec48.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# --------------------------------------------------------------------------
# top publishers by global seles horizontal
#
# the best publusher is nintendo have height sales
#
# NA_Sales dominates with the highest total sales, exceeding 4000 million.
# EU_Sales follows with a total sales figure around 2400 million.
# JP_Sales records a lower figure than EU_Sales, slightly exceeding 1200 million in total sales.
# Other_Sales has the lowest total sales among the four regions, reaching approximately 800 million.
# The chart clearly demonstrates that the North American region represents the largest market share for sales.
#
# ![WhatsApp Image 2024-09-22 at 22.02.05_f6bc0112.jpg](data:image/jpeg;base64,...)
# --------------------------------------------------------------------------
# yearly video games sales trend.
#
# trend from 2005 to 2012
#
# In early 2012, smartphones began to appear, which led to a decrease in demand for games.
#
# he product or service analyzed might be more popular or widely adopted in North America.
# Distribution channels or marketing strategies could be more effective in North America.
# The data might reflect regional variations in population, purchasing power, or cultural preferences.
# Further Analysis:
#
# Investigate the underlying reasons for North America's dominance in sales.
# Analyze trends in each region over time to identify growth patterns.
# Compare these sales figures to market share and competitor performance in each region.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Which genres are most popular on specific gaming platforms?
#
# action games in ps2  ps3 psp and ps4
#
# fighting in 360  DS and xone
#
# sports in wii and 3DS.
#
# ![WhatsApp Image 2024-09-23 at 13.14.25_e33113b1.jpg](data:image/jpeg;base64,...)
# --------------------------------------------------------------------------
#
# Regional Sales Variation by Genre in North America
#
# This report provides an analysis of the total sales performance across four regions: North America (NA_Sales), Europe (EU_Sales), Japan (JP_Sales), and Other regions (Other_Sales).
#
# Regional Sales Distribution: North America accounts for the largest share of total sales, followed by Europe, Japan, and Other regions.
# Sales Volume: The total sales volume for North America exceeds 4000 million, while Europe and Japan have sales volumes of around 2400 million and 1200 million, respectively. Other regions have a sales volume of approximately 800 million.
# Regional Sales Ratio: The sales ratio of North America to Europe is approximately 1.67:1, indicating that North America generates nearly 1.67 times more sales than Europe.
#
# Conduct a deeper analysis of sales trends and customer behavior in North America to identify opportunities for growth.
# Develop targeted marketing campaigns to increase sales in Europe.
# Review and refine sales strategies in Japan and Other regions to improve sales performance.
#
#
# ![WhatsApp Image 2024-09-23 at 13.21.27_843d452a.jpg](data:image/jpeg;base64,...)
#
# --------------------------------------------------------------------------
#
# correlations between game sales and other factors
#
# This report provides an in-depth analysis of the market trends, customer behavior, and competitor landscape in the industry. The report highlights key findings, insights, and recommendations to inform business decisions and drive growth.
#
# Growing Demand: The market is experiencing a steady growth rate of 5% YoY, driven by increasing demand for innovative products and services.
# Shifting Consumer Behavior: Consumers are becoming more digitally savvy, with 70% of customers preferring online channels for research and purchasing.
# Emerging Technologies: The adoption of emerging technologies such as AI, IoT, and blockchain is transforming the industry, creating new opportunities and challenges.
#
# ![image.png](data:image/png;base64,...)
# --------------------------------------------------------------------------
#
# video games sales over time
#
# from(1980 to 1995)->total sales=100milions
# from(1995 to 2000)->total sales increase to 200 milions
# from(2000 t0 2005)-> total sales increase to 450 milions
# from(2007 to 2010) top of sales 670 milions
# from (2010 to 2020) sales are down
#
#
# ![WhatsApp Image 2024-09-23 at 13.43.18_7c876633.jpg](data:image/jpeg;base64,...)
# --------------------------------------------------------------------------
#
# sales trends over the years in each region
# (North_america,Europe,japan,Rest_of_the_world)
#
# north_america the best sales over the years
#
# from 1980 to 1985 north america have the best sales from
#
# ![WhatsApp Image 2024-09-23 at 13.49.00_c5fa75de.jpg](data:image/jpeg;base64,...)
# --------------------------------------------------------------------------
#
# percentage of the global video game market using pie chart
#
# NA_sales have the most gaming sales
#
# This chart shows the total video game sales by region, measured in millions. The x-axis lists the different regions: NA_Sales (North America), EU_Sales (Europe), JP_Sales (Japan), and Other_Sales. The y-axis represents the total sales in millions.
#
# North America is the largest market: With over 4,000 million in sales, it significantly surpasses other regions.
# Europe follows: Europe sits in second place with sales around 2,400 million.
# Japan and Other regions are comparable: Japan's sales are slightly above 1,200 million while other regions combined total just under 800 million.
#
#
# ![WhatsApp Image 2024-09-23 at 13.53.44_3c7ffd66.jpg](data:image/jpeg;base64,...)
# --------------------------------------------------------------------------
